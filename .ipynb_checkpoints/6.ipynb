# %% [markdown]
# # Лабораторная работа 5 Покотило Дмитрий ПИН-201

# %% [markdown]
# ### 1 - Считать в pandas DataFrame любой источник данных: CSV, JSON, Excel-файл, HTML-таблицу, встроенный датасет sklearn.
#    ###   - Опишите ваши данные, что обозначает каждый столбец, какого типа (категориальный, вещественный, целочисленный, бинарный) данный столбец, при необходимости для категориальных в том числе бинарных признаков привести расшифровку их значений. В общем, проведите "визуальный" анализ ваших данных.

# %% [markdown]
# Подключение библиотек

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Читаем в переменную rests файл с индийскими ресторанами

# %%
rests  = pd.read_csv('restaurants.csv', sep=',', nrows=6594)

# %% [markdown]
# ## 2 Выполните с датафреймом следующие операции (многие операции можно совершить не одним способом, используйте все известные вам способы, поищите/придумайте новые способы) :

# %% [markdown]
# ### 2.1 вывод таблицы

# %%
rests
# Out:
#                                 Name  \
# 0                              Local
# 1                      The G.T. ROAD
# 2                            Tamasha
# 3                  The Junkyard Cafe
# 4     Chili's American Grill and Bar
# ...                              ...
# 6588                   Shree Rathnam
# 6589                     Cafe Delish
# 6590                     3 K Resorts
# 6591                       Dovka Bar
# 6592                     Urban Vibes
#
#                                                Location           Locality  \
# 0          Scindia House,Connaught Place, Central Delhi      Central Delhi
# 1                M-Block,Connaught Place, Central Delhi      Central Delhi
# 2                        Connaught Place, Central Delhi      Central Delhi
# 3                        Connaught Place, Central Delhi      Central Delhi
# 4                M-Block,Connaught Place, Central Delhi      Central Delhi
# ...

# %% [markdown]
# ### Результат "визуального" анализа:
#     -Name: наименование ресторана. (строковый)
#     -Locality: расположение ресторана. (строковый)
#     -Location: район. (строковый)
#     -City: город. (строковый)
#     -Cuisine: основная кухня. (строковый)
#     -Rating: средний рейтинг. (число с плавающей точкой)
#     -Votes: количество полученных голосов. (числовой)
#     -Cost: цена. (числовой)

# %% [markdown]
# ### 2.2 вывод первых 5 элементов таблицы

# %%
rests.head(5)
# Out:
#                              Name  \
# 0                           Local
# 1                   The G.T. ROAD
# 2                         Tamasha
# 3               The Junkyard Cafe
# 4  Chili's American Grill and Bar
#
#                                        Location        Locality   City  \
# 0  Scindia House,Connaught Place, Central Delhi   Central Delhi  Delhi
# 1        M-Block,Connaught Place, Central Delhi   Central Delhi  Delhi
# 2                Connaught Place, Central Delhi   Central Delhi  Delhi
# 3                Connaught Place, Central Delhi   Central Delhi  Delhi
# 4        M-Block,Connaught Place, Central Delhi   Central Delhi  Delhi
#
#                                              Cuisine  Rating  Votes  Cost
# 0           North Indian,  Finger Food,  Continental     4.1   2415  2000
# 1                                       North Indian     4.3   2363  1500
# 2  Finger Food,  North Indian,  Italian,  Contine...     4.2   5016  2000
# ...

# %% [markdown]
# ### 2.3 вывод последних 5 элементов таблицы

# %%
rests.tail(5)
# Out:
#                Name                                           Location  \
# 6588  Shree Rathnam                 Wave Mall,BRS Nagar, West Ludhiana
# 6589    Cafe Delish          Radisson Blu,Rajguru Nagar, West Ludhiana
# 6590    3 K Resorts                           BRS Nagar, West Ludhiana
# 6591      Dovka Bar  Nirvana Hotel Banquets Club,PAU, Central Ludhiana
# 6592    Urban Vibes                         Aggar Nagar, West Ludhiana
#
#                Locality      City  \
# 6588      West Ludhiana  Ludhiana
# 6589      West Ludhiana  Ludhiana
# 6590      West Ludhiana  Ludhiana
# 6591   Central Ludhiana  Ludhiana
# 6592      West Ludhiana  Ludhiana
#
#                                                 Cuisine  Rating  Votes  Cost
# 6588                                       South Indian     4.1     20   600
# 6589  Multi-Cuisine,  North Indian,  Continental,  A...     4.4     48  3100
# 6590                                       North Indian     1.0      1  1100
# ...

# %% [markdown]
# ### 2.4 использовать функцию describe()
# Получаем статистику по числовым значениям(рейтинг, голоса, цена).

# %%
rests.describe().round()
# Out:
#        Rating   Votes    Cost
# count  6593.0  6593.0  6593.0
# mean      4.0   119.0  1103.0
# std       1.0   262.0   717.0
# min       1.0     1.0   100.0
# 25%       4.0     6.0   500.0
# 50%       4.0    31.0   900.0
# 75%       4.0   115.0  1500.0
# max       5.0  5016.0  8000.0

# %% [markdown]
# ### 2.5 считывание значения конкретной ячейки (с конкретным индексом из конкретной колонки) всеми известными вам способами

# %%
rests.iloc[0]['Name']
# Out:
# 'Local'

# %%
rests.at[0, 'Name']
# Out:
# 'Local'

# %%
rests['Name'].values[0]
# Out:
# 'Local'

# %%
rests.iat[0, 0]
# Out:
# 'Local'

# %%
rests._get_value(0, 'Name')
# Out:
# 'Local'

# %% [markdown]
# ### 2.6 фильтрация строк по диапазону индекса

# %% [markdown]
# Задаём список для фильтрации

# %%
list_for_filter = [1,2,3,5]

rests[rests.index.isin (list_for_filter)]
# Out:
#                               Name                                Location  \
# 1                    The G.T. ROAD  M-Block,Connaught Place, Central Delhi
# 2                          Tamasha          Connaught Place, Central Delhi
# 3                The Junkyard Cafe          Connaught Place, Central Delhi
# 5  Ardor 2.1 Restaurant and Lounge          Connaught Place, Central Delhi
#
#          Locality   City                                            Cuisine  \
# 1   Central Delhi  Delhi                                       North Indian
# 2   Central Delhi  Delhi  Finger Food,  North Indian,  Italian,  Contine...
# 3   Central Delhi  Delhi  North Indian,  Mediterranean,  Asian,  Italian...
# 5   Central Delhi  Delhi  Multi-Cuisine,  North Indian,  Italian,  Chine...
#
#    Rating  Votes  Cost
# 1     4.3   2363  1500
# 2     4.2   5016  2000
# 3     4.2   2821  1800
# 5     3.9   1391  2000

# %%
rests[rests.index.isin ([1, 2, 3 , 5])]
# Out:
#                               Name                                Location  \
# 1                    The G.T. ROAD  M-Block,Connaught Place, Central Delhi
# 2                          Tamasha          Connaught Place, Central Delhi
# 3                The Junkyard Cafe          Connaught Place, Central Delhi
# 5  Ardor 2.1 Restaurant and Lounge          Connaught Place, Central Delhi
#
#          Locality   City                                            Cuisine  \
# 1   Central Delhi  Delhi                                       North Indian
# 2   Central Delhi  Delhi  Finger Food,  North Indian,  Italian,  Contine...
# 3   Central Delhi  Delhi  North Indian,  Mediterranean,  Asian,  Italian...
# 5   Central Delhi  Delhi  Multi-Cuisine,  North Indian,  Italian,  Chine...
#
#    Rating  Votes  Cost
# 1     4.3   2363  1500
# 2     4.2   5016  2000
# 3     4.2   2821  1800
# 5     3.9   1391  2000

# %% [markdown]
# ### 2.7 фильтрация набора данных по какому-либо условию

# %% [markdown]
# фильтруем, чтобы выводились значения, если в колонке 'Name' имя начинается с T

# %%
rests[rests.Name.str.startswith('T')]
# Out:
#                               Name                                Location  \
# 1                    The G.T. ROAD  M-Block,Connaught Place, Central Delhi
# 2                          Tamasha          Connaught Place, Central Delhi
# 3                The Junkyard Cafe          Connaught Place, Central Delhi
# 6       The Luggage Room By Sandoz  M-Block,Connaught Place, Central Delhi
# 22         The Darzi Bar & Kitchen          Connaught Place, Central Delhi
# ...                            ...                                     ...
# 6573  The Beer Garden by Peddler's        Ferozepur Road, Central Ludhiana
# 6574            The Crispy Hawkers                BRS Nagar, West Ludhiana
# 6575            The Chocolate Room            Sarabha Nagar, West Ludhiana
# 6583   The Biker's Sky Lounge Cafe            Sarabha Nagar, West Ludhiana
# 6584         The Yard Lounge & Bar            Pakhowal Road, West Ludhiana
#
#                Locality      City  \
# ...

# %% [markdown]
# фильтруем, 5 самых больших значений по цене

# %%
rests.nlargest(5, 'Cost')
# Out:
#            Name                                     Location        Locality  \
# 1672     Masque   Laxmi Woolen Mills,Mahalaxmi, South Mumbai    South Mumbai
# 632       Kheer          Roseate House,Aerocity, South Delhi     South Delhi
# 119     Sevilla  The Claridges,Aurangzeb Road, Central Delhi   Central Delhi
# 199   Le Cirque   The Leela Palace,Chanakyapuri, South Delhi     South Delhi
# 202    The Qube   The Leela Palace,Chanakyapuri, South Delhi     South Delhi
#
#         City                                       Cuisine  Rating  Votes  \
# 1672  Mumbai                      European,  Modern Indian     4.6     26
# 632    Delhi                        North Indian,  Mughlai     4.6    302
# 119    Delhi                             Italian,  Spanish     4.5    306
# 199    Delhi                Italian,  Continental,  French     4.4     25
# 202    Delhi  North Indian,  Italian,  Continental,  Asian     4.5     84
#
#       Cost
# 1672  8000
# 632   6000
# 119   5000
# ...

# %% [markdown]
# фильтруем, 5 самых маленьких значений по цене

# %%
rests.nsmallest(5, 'Cost')
# Out:
#                Name                                           Location  \
# 4764    Gokul Shree                             Alipore, South Kolkata
# 4826      Bake Club                            Jadavpur, South Kolkata
# 1149  Tibbs Frankie        R City Mall,Ghatkopar West, Central Suburbs
# 1173  Tibbs Frankie  Phoenix Marketcity Mall,Kurla West, Central Su...
# 1215  Tibbs Frankie                           Chembur, Central Suburbs
#
#               Locality     City                   Cuisine  Rating  Votes  Cost
# 4764     South Kolkata  Kolkata               Street Food     3.5      2   100
# 4826     South Kolkata  Kolkata  Bakery and Confectionary     1.0      1   100
# 1149   Central Suburbs   Mumbai                 Fast Food     3.3      6   200
# 1173   Central Suburbs   Mumbai                 Fast Food     4.4     41   200
# 1215   Central Suburbs   Mumbai                 Fast Food     4.7     40   200

# %% [markdown]
# фильтруем, чтобы выводились значения, если в колонке 'Name' содержится буква 'y'

# %%
rests[rests.Name.str.contains('y')]
# Out:
#                                 Name  \
# 3                  The Junkyard Cafe
# 6         The Luggage Room By Sandoz
# 8                      My Bar Square
# 13               Unplugged Courtyard
# 15                  Ministry Of Beer
# ...                              ...
# 6574              The Crispy Hawkers
# 6579  Spice Roots By Hotel Rigal Blu
# 6583     The Biker's Sky Lounge Cafe
# 6585                    Sixtynine.ml
# 6587                    Hungry Point
#
#                                       Location           Locality      City  \
# 3               Connaught Place, Central Delhi      Central Delhi     Delhi
# 6       M-Block,Connaught Place, Central Delhi      Central Delhi     Delhi
# 8               Connaught Place, Central Delhi      Central Delhi     Delhi
# 13              Connaught Place, Central Delhi      Central Delhi     Delhi
# 15      M-Block,Connaught Place, Central Delhi      Central Delhi     Delhi
# ...

# %% [markdown]
# фильтруем  по цене больше или равно 2000 и рейтингу 5

# %%
rests[(rests.Cost >= 2000) & (rests.Rating == 5.0)]
# Out:
#                      Name                                           Location  \
# 722                 Ethyl                    Radisson Noida,Sector 55, Noida
# 1085        Houz Cafe Bar                                 Sector 65, Gurgaon
# 1662  Farmhouse Palladium                       Borivali West, North Western
# 1865               Mirage                     Ashok Nagar, Central Bangalore
# 5676             Tamarind  Shakun Hotels and Resorts,C Scheme, Central Ja...
# 5984              Pepperz                Scorpio Club,Aliganj, North Lucknow
# 6217                  Ark                         Hiran Magri, South Udaipur
# 6293       The Restaurant             Trident  Hotel Agra,Tajganj, East Agra
# 6299                Tapas  Jaypee Palace Hotel & Convention Centre,Tajgan...
# 6457    The Latest Recipe       Le Méridien Nagpur,Wardha Road, South Nagpur
# 6458            Longitude       Le Méridien Nagpur,Wardha Road, South Nagpur
# ...

# %% [markdown]
# фильтруем  по рейтингу 3 или 5

# %%
rests[(rests.Rating == 5.0) | (rests.Rating == 3.0)]
# Out:
#                                Name  \
# 72                   Mughal-E-Hazam
# 84                        Bistro 55
# 85                            Giani
# 115           Thalassery Restaurant
# 134                  The Waffle Co.
# ...                             ...
# 6557  Basant Ice Cream Cafe & Foods
# 6559                        Karim's
# 6560                    Silver Leaf
# 6574             The Crispy Hawkers
# 6577                      Roli Poli
#
#                                                Location           Locality  \
# 72                       Connaught Place, Central Delhi      Central Delhi
# 84                             Paharganj, Central Delhi      Central Delhi
# 85                       Connaught Place, Central Delhi      Central Delhi
# 115                          Rajinder Nagar, West Delhi         West Delhi
# 134                          Rajinder Nagar, West Delhi         West Delhi
# ...

# %% [markdown]
# ### 2.8 работа с пропущенными значениями (если они есть): удаление строк с пропущенными значениями, заполнение пропущенных значений средним значением по колонке. Если пропущенных значений нет — намеренно их "генерируете", прибивая какие-то куски данных в np.nan

# %% [markdown]
# #### "генерируем" пропущенные значения

# %%
rests.at[0,'Cost'] = np.nan
rests.at[1,'Cost'] = np.nan
rests.at[2,'Cost'] = np.nan

rests
# Out:
#                                 Name  \
# 0                              Local
# 1                      The G.T. ROAD
# 2                            Tamasha
# 3                  The Junkyard Cafe
# 4     Chili's American Grill and Bar
# ...                              ...
# 6588                   Shree Rathnam
# 6589                     Cafe Delish
# 6590                     3 K Resorts
# 6591                       Dovka Bar
# 6592                     Urban Vibes
#
#                                                Location           Locality  \
# 0          Scindia House,Connaught Place, Central Delhi      Central Delhi
# 1                M-Block,Connaught Place, Central Delhi      Central Delhi
# 2                        Connaught Place, Central Delhi      Central Delhi
# 3                        Connaught Place, Central Delhi      Central Delhi
# 4                M-Block,Connaught Place, Central Delhi      Central Delhi
# ...

# %% [markdown]
# #### удаление пропущенных значений

# %%
rests.dropna(subset='Cost')
# Out:
#                                  Name  \
# 3                   The Junkyard Cafe
# 4      Chili's American Grill and Bar
# 5     Ardor 2.1 Restaurant and Lounge
# 6          The Luggage Room By Sandoz
# 7                                 QBA
# ...                               ...
# 6588                    Shree Rathnam
# 6589                      Cafe Delish
# 6590                      3 K Resorts
# 6591                        Dovka Bar
# 6592                      Urban Vibes
#
#                                                Location           Locality  \
# 3                        Connaught Place, Central Delhi      Central Delhi
# 4                M-Block,Connaught Place, Central Delhi      Central Delhi
# 5                        Connaught Place, Central Delhi      Central Delhi
# 6                M-Block,Connaught Place, Central Delhi      Central Delhi
# 7                        Connaught Place, Central Delhi      Central Delhi
# ...

# %% [markdown]
# #### заполнение пропущенных значений средним значением по колонке

# %%
rests.fillna(rests['Cost'].mean().round())
# Out:
#                                 Name  \
# 0                              Local
# 1                      The G.T. ROAD
# 2                            Tamasha
# 3                  The Junkyard Cafe
# 4     Chili's American Grill and Bar
# ...                              ...
# 6588                   Shree Rathnam
# 6589                     Cafe Delish
# 6590                     3 K Resorts
# 6591                       Dovka Bar
# 6592                     Urban Vibes
#
#                                                Location           Locality  \
# 0          Scindia House,Connaught Place, Central Delhi      Central Delhi
# 1                M-Block,Connaught Place, Central Delhi      Central Delhi
# 2                        Connaught Place, Central Delhi      Central Delhi
# 3                        Connaught Place, Central Delhi      Central Delhi
# 4                M-Block,Connaught Place, Central Delhi      Central Delhi
# ...

# %% [markdown]
# ### 2.9. создание нового поля вычисленного на основе значений других полей:

# %% [markdown]
# #### 2.9.1 через выражение на базе имеющихся колонок,

# %%
new = [rests.Name.sample(n=1, random_state=1), rests.Location.sample(n=1, random_state=1), rests.Locality.sample(n=1, random_state=1), rests.City.sample(n=1, random_state=1), rests.Cuisine.sample(n=1, random_state=1), rests.Rating.mean().round(), rests.Votes.mean().round(), rests.Cost.mean().round()]
rests.append(pd.Series (new, index=rests.columns [: len (new)]), ignore_index= True )
#rests.Name.sample(n=1, random_state=1)
# Out:
# C:\Users\niki3\AppData\Local\Temp\ipykernel_16168\3138651037.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   rests.append(pd.Series (new, index=rests.columns [: len (new)]), ignore_index= True )
#                                                 Name  \
# 0                                              Local
# 1                                      The G.T. ROAD
# 2                                            Tamasha
# 3                                  The Junkyard Cafe
# 4                     Chili's American Grill and Bar
# ...                                              ...
# 6589                                     Cafe Delish
# 6590                                     3 K Resorts
# 6591                                       Dovka Bar
# 6592                                     Urban Vibes
# 6593  2821    Lassi Corner
# Name: Name, dtype: object
#
# ...

# %% [markdown]
# #### 2.9.2 через DataFrame.apply

# %%
rests['CITIES'] = rests['City'].apply(lambda element: element.upper())

rests
# Out:
#                                 Name  \
# 0                              Local
# 1                      The G.T. ROAD
# 2                            Tamasha
# 3                  The Junkyard Cafe
# 4     Chili's American Grill and Bar
# ...                              ...
# 6588                   Shree Rathnam
# 6589                     Cafe Delish
# 6590                     3 K Resorts
# 6591                       Dovka Bar
# 6592                     Urban Vibes
#
#                                                Location           Locality  \
# 0          Scindia House,Connaught Place, Central Delhi      Central Delhi
# 1                M-Block,Connaught Place, Central Delhi      Central Delhi
# 2                        Connaught Place, Central Delhi      Central Delhi
# 3                        Connaught Place, Central Delhi      Central Delhi
# 4                M-Block,Connaught Place, Central Delhi      Central Delhi
# ...

# %% [markdown]
# #### 2.9.3 через Series.apply

# %%
def func(row):
    if "Central Delhi" in row['Locality']:
        return 'not eat'
    else: 
        return 'eat'
    
    
    
rests['eat'] = rests.apply(func, axis=1)


rests
# Out:
#       index                            Name  \
# 0         0                           Local
# 1         1                   The G.T. ROAD
# 2         2                         Tamasha
# 3         3               The Junkyard Cafe
# 4         4  Chili's American Grill and Bar
# ...     ...                             ...
# 6588   6588                   Shree Rathnam
# 6589   6589                     Cafe Delish
# 6590   6590                     3 K Resorts
# 6591   6591                       Dovka Bar
# 6592   6592                     Urban Vibes
#
#                                                Location           Locality  \
# 0          Scindia House,Connaught Place, Central Delhi      Central Delhi
# 1                M-Block,Connaught Place, Central Delhi      Central Delhi
# 2                        Connaught Place, Central Delhi      Central Delhi
# 3                        Connaught Place, Central Delhi      Central Delhi
# ...

# %% [markdown]
# #### 2.10 сортировка по какому-либо из полей

# %% [markdown]
# сортировка строк данных на основе 'Rating', начиная с 5 звёзд

# %%
rests.sort_values(by = 'Rating', ascending = False)
# Out:
#       index               Name  \
# 1906   1906  Sreeraj Lassi Bar
# 2285   2285       Coco Barista
# 1296   1296    The Food Master
# 6293   6293     The Restaurant
# 5814   5814      Grab A Coffee
# ...     ...                ...
# 5523   5523        Bada Saab's
# 3421   3421              Petoo
# 5837   5837           De Thali
# 1107   1107          Grill Inn
# 624     624              Giani
#
#                                                Location  \
# 1906                   Shivaji Nagar, Central Bangalore
# 2285                        BTM Layout, South Bangalore
# 1296                                 Vashi, Navi Mumbai
# 6293             Trident  Hotel Agra,Tajganj, East Agra
# 5814                        Malviya Nagar, South Jaipur
# ...                                                 ...
# 5523                                    Phase 3, Mohali
# 3421                   Ameerpet, Central East Hyderabad
# 5837                             Raja Park, East Jaipur
# ...

# %% [markdown]
# #### 2.11 вычислить несколько статистик по колонкам (используйте встроенные агрегатные функции — любые на выбор)

# %% [markdown]
# среднее значение для числовых столбцов

# %%
rests.mean(numeric_only=True)
# Out:
# index     3296.000000
# Rating       4.088200
# Votes      119.420143
# Cost      1102.465706
# dtype: float64

# %% [markdown]
# стандартное отклонение для числовых столбцов

# %%
rests.std(numeric_only=True)
# Out:
# index     1903.379494
# Rating       0.670031
# Votes      261.849704
# Cost       716.911242
# dtype: float64

# %% [markdown]
# Минимальные значения столбцов

# %%
rests.min(numeric_only=True)
# Out:
# index       0.0
# Rating      1.0
# Votes       1.0
# Cost      100.0
# dtype: float64

# %% [markdown]
# Максимальные значения столбцов

# %%
rests.max(numeric_only=True)
# Out:
# index     6592.0
# Rating       5.0
# Votes     5016.0
# Cost      8000.0
# dtype: float64

# %% [markdown]
# Количество наименований ресторанов

# %%
rests.Name.count()
# Out:
# 6593

# %% [markdown]
# Считаем медиану каждого столбца

# %%
rests.median(numeric_only=True)
# Out:
# index     3296.0
# Rating       4.2
# Votes       31.0
# Cost       900.0
# dtype: float64

# %% [markdown]
# #### 2.12 .value_counts()

# %% [markdown]
# Подсчет уникальных значений строковых столбцов

# %%
rests.Name.value_counts()
# Out:
# Wow! Momo                        67
# Kanti Sweets                     65
# Barbeque Nation                  48
# Taco Bell                        44
# Dindigul Thalappakatti           33
#                                  ..
# Churn                             1
# Swagatham Rayalaseema Ruchulu     1
# BYLI - Bet You Love It            1
# Chameleon Lounge Bar              1
# Urban Vibes                       1
# Name: Name, Length: 4520, dtype: int64

# %%
rests.Location.value_counts()
# Out:
# Koramangala, South Bangalore                                   66
# Indiranagar, East Bangalore                                    53
# Jubilee Hills, Central West Hyderabad                          51
# Connaught Place, Central Delhi                                 49
# Salt Lake, East Kolkata                                        49
#                                                                ..
# Purva Riviera Shopping Complex,Marathahalli, East Bangalore     1
# Kasavanahalli, South Bangalore                                  1
# KR Inn,KR Puram, East Bangalore                                 1
# Venkataswamy Building,Marathahalli, East Bangalore              1
# Nirvana Hotel Banquets Club,PAU, Central Ludhiana               1
# Name: Location, Length: 2399, dtype: int64

# %%
rests.Locality.value_counts()
# Out:
#  South Bangalore                364
#  South Delhi                    339
#  South Kolkata                  310
#  West Ahmedabad                 236
#  East Bangalore                 235
#                                ...
#  North Kochi                      1
#  East Kochi                       1
#  East Udaipur                     1
#  North Mysore                     1
#  Bangalore Mangalore Highway      1
# Name: Locality, Length: 108, dtype: int64

# %%
rests.City.value_counts()
# Out:
# Bangalore     1019
# Delhi          734
# Mumbai         727
# Kolkata        712
# Hyderabad      589
# Ahmedabad      414
# Chennai        388
# Pune           351
# Jaipur         268
# Chandigarh     264
# Indore         204
# Gurgaon        184
# Noida          146
# Vadodara        91
# Lucknow         80
# Agra            75
# Nagpur          66
# Surat           64
# Ludhiana        62
# Goa             60
# Ghaziabad       50
# Udaipur         43
# Kochi            2
# Name: City, dtype: int64

# %%
rests.Cuisine.value_counts()
# Out:
# North Indian,  Chinese                                              294
# Fast Food                                                           167
# North Indian                                                        150
# North Indian,  Chinese,  Continental                                146
# North Indian,  Mughlai                                              128
#                                                                    ...
# Bihari,  Seafood                                                      1
# Japanese,  Asian,  Thai,  Korean                                      1
# Italian,  Mexican,  Continental,  Street Food                         1
# Multi-Cuisine,  North Indian,  Chinese,  Assamese                     1
# Multi-Cuisine,  North Indian,  Continental,  Asian,  Health Food      1
# Name: Cuisine, Length: 2096, dtype: int64

# %% [markdown]
# #### 2.13 Вывод уникальных значений колонки через .unique()

# %%
rests.Name.unique()
# Out:
# array(['Local', 'The G.T. ROAD', 'Tamasha', ..., '3 K Resorts',
#        'Dovka Bar', 'Urban Vibes'], dtype=object)

# %%
rests.Location.unique()
# Out:
# array(['Scindia House,Connaught Place, Central Delhi',
#        'M-Block,Connaught Place, Central Delhi',
#        'Connaught Place, Central Delhi', ...,
#        'Wave Mall,BRS Nagar, West Ludhiana',
#        'Radisson Blu,Rajguru Nagar, West Ludhiana',
#        'Nirvana Hotel Banquets Club,PAU, Central Ludhiana'], dtype=object)

# %%
rests.Locality.unique()
# Out:
# array([' Central Delhi', ' North Delhi', ' West Delhi', ' South Delhi',
#        ' East Delhi', ' Noida', ' Ghaziabad', ' Gurgaon', ' Faridabad',
#        ' NCR Greater Noida', ' Central Suburbs', ' Andheri East',
#        ' Powai', ' Bandra', ' South Mumbai', ' Andheri West',
#        ' Navi Mumbai', ' North Western', ' Thane', ' Dombivali',
#        ' Central Bangalore', ' South Bangalore', ' West Bangalore',
#        ' East Bangalore', ' North Bangalore', ' Mysore Highway',
#        ' Bangalore Mangalore Highway', ' North Mysore',
#        ' Central Chennai', ' South West Chennai', ' West Chennai',
#        ' North Chennai', ' South Chennai', ' Central East Hyderabad',
#        ' Secunderabad', ' Central West Hyderabad', ' Central Hyderabad',
#        ' West Hyderabad', ' South Hyderabad', ' East Hyderabad',
#        ' West Pune', ' East Pune', ' South Pune', ' East Kolkata',
#        ' Central Kolkata', ' North Kolkata', ' South Kolkata', ' Howrah',
# ...

# %%
rests.City.unique()
# Out:
# array(['Delhi', 'Noida', 'Ghaziabad', 'Gurgaon', 'Mumbai', 'Bangalore',
#        'Chennai', 'Hyderabad', 'Pune', 'Kolkata', 'Ahmedabad',
#        'Chandigarh', 'Goa', 'Jaipur', 'Lucknow', 'Indore', 'Udaipur',
#        'Agra', 'Vadodara', 'Nagpur', 'Kochi', 'Surat', 'Ludhiana'],
#       dtype=object)

# %%
rests.Cuisine.unique()
# Out:
# array(['North Indian,  Finger Food,  Continental', 'North Indian',
#        'Finger Food,  North Indian,  Italian,  Continental,  Asian', ...,
#        'North Indian,  European,  Asian,  Finger Food',
#        'Multi-Cuisine,  North Indian,  Continental,  Asian,  Sizzlers',
#        'Multi-Cuisine,  North Indian,  Continental,  Asian,  Health Food'],
#       dtype=object)

# %% [markdown]
# #### 2.14 Удалите текущий индекс и создайте новый индекс на базе новой колонки, которая для этого лучше всего подходит

# %%
rests.reset_index(inplace= True )

rests
# Out:
#       level_0  index                            Name  \
# 0           0      0                           Local
# 1           1      1                   The G.T. ROAD
# 2           2      2                         Tamasha
# 3           3      3               The Junkyard Cafe
# 4           4      4  Chili's American Grill and Bar
# ...       ...    ...                             ...
# 6588     6588   6588                   Shree Rathnam
# 6589     6589   6589                     Cafe Delish
# 6590     6590   6590                     3 K Resorts
# 6591     6591   6591                       Dovka Bar
# 6592     6592   6592                     Urban Vibes
#
#                                                Location           Locality  \
# 0          Scindia House,Connaught Place, Central Delhi      Central Delhi
# 1                M-Block,Connaught Place, Central Delhi      Central Delhi
# 2                        Connaught Place, Central Delhi      Central Delhi
# ...

# %% [markdown]
# Удалили старый индекс, но оставили его столбцом, чтобы назначить его заново, т.к. он подходит лучше всех

# %%
rests.set_index('index')
# Out:
#        level_0                            Name  \
# index
# 0            0                           Local
# 1            1                   The G.T. ROAD
# 2            2                         Tamasha
# 3            3               The Junkyard Cafe
# 4            4  Chili's American Grill and Bar
# ...        ...                             ...
# 6588      6588                   Shree Rathnam
# 6589      6589                     Cafe Delish
# 6590      6590                     3 K Resorts
# 6591      6591                       Dovka Bar
# 6592      6592                     Urban Vibes
#
#                                                 Location           Locality  \
# index
# 0           Scindia House,Connaught Place, Central Delhi      Central Delhi
# 1                 M-Block,Connaught Place, Central Delhi      Central Delhi
# 2                         Connaught Place, Central Delhi      Central Delhi
# ...
